# %%
#Failide lugemiseks Colabis
import os
from google.colab import drive
drive.mount('/content/drive')
os.chdir("/content/drive/My Drive/Colab Notebooks/Andmeteadus/Projekt/DataScienceProject")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %% [markdown]
# # New section

# %%
Kaggle_data = pd.read_csv("Kaggle_data.csv", encoding="latin-1")
Kaggle_data
# Out:
#                                 Track                        Album Name  \
# 0                 MILLION DOLLAR BABY      Million Dollar Baby - Single
# 1                         Not Like Us                       Not Like Us
# 2          i like the way you kiss me        I like the way you kiss me
# 3                             Flowers                  Flowers - Single
# 4                             Houdini                           Houdini
# ...                               ...                               ...
# 4595                For the Last Time                 For the Last Time
# 4596                 Dil Meri Na Sune  Dil Meri Na Sune (From "Genius")
# 4597            Grace (feat. 42 Dugg)                           My Turn
# 4598              Nashe Si Chadh Gayi             November Top 10 Songs
# 4599  Me Acostumbre (feat. Bad Bunny)   Me Acostumbre (feat. Bad Bunny)
#
#               Artist Release Date          ISRC All Time Rank  Track Score  \
# ...

# %%
Kaggle_data
# Out:
#                                 Track                        Album Name  \
# 0                 MILLION DOLLAR BABY      Million Dollar Baby - Single
# 1                         Not Like Us                       Not Like Us
# 2          i like the way you kiss me        I like the way you kiss me
# 3                             Flowers                  Flowers - Single
# 4                             Houdini                           Houdini
# ...                               ...                               ...
# 4595                For the Last Time                 For the Last Time
# 4596                 Dil Meri Na Sune  Dil Meri Na Sune (From "Genius")
# 4597            Grace (feat. 42 Dugg)                           My Turn
# 4598              Nashe Si Chadh Gayi             November Top 10 Songs
# 4599  Me Acostumbre (feat. Bad Bunny)   Me Acostumbre (feat. Bad Bunny)
#
#               Artist Release Date          ISRC All Time Rank  Track Score  \
# ...

# %%
Mined_data
# Out:
#       Artist  Id  Genres  New Name             name                      id
# 0        NaN NaN     NaN       NaN    Tommy Richman  1WaFQSHVGZQJTbf0BdxdNo
# 1        NaN NaN     NaN       NaN   Kendrick Lamar  2YZyLoL8N0Wb9xBt1NhZWg
# 2        NaN NaN     NaN       NaN          Artemas  0PCCGZ0wGLizHt2KZ7hhA2
# 3        NaN NaN     NaN       NaN      Miley Cyrus  5YGY8feqx7naU7z4HrwZM6
# 4        NaN NaN     NaN       NaN           Eminem  7dGJo4pcD2V6oG8kP0tJRR
# ...      ...  ..     ...       ...              ...                     ...
# 1995     NaN NaN     NaN       NaN         Serranow  38NpF2cwENnpQ3P19UnyUP
# 1996     NaN NaN     NaN       NaN            Steps  17UkABEasVRlCcIFZ3wHb7
# 1997     NaN NaN     NaN       NaN       Kerim Araz  2xNgzwX6A9orF0QEJph5Eb
# 1998     NaN NaN     NaN       NaN  Jaques RaupÃ¯Â¿  7BPiWKbeuWueq4qGMz3A0T
# 1999     NaN NaN     NaN       NaN      BUSHIDO ZHO  27kGBCjiz5OXojkKX4xQ6R
#
# [2000 rows x 6 columns]

# %%
Combined_data = pd.merge(Kaggle_data, Mined_data, on="Artist", how="inner")
Combined_data
